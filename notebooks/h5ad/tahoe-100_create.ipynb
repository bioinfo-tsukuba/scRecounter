# %% [markdown]
# # Goals
#
# * Create tahoe-100 dataset on GCP
# * Description of the [metadata](https://docs.google.com/spreadsheets/d/18lu5agCNbgWsjZ9K05Mf65z1RseoFqsi/edit?usp=sharing&ouid=103963277960448548043&rtpof=true&sd=true)

# %% [markdown]
# # Var

# %%
work_dir = '/processed_datasets/scRecount/tahoe'
gcp_dir = 'gs://arc-ctc-tahoe100/2025-02-25/'

# %% [markdown]
# # Init

# %%
import os
import sys
import gcsfs
from glob import glob
import pandas as pd
import scanpy as sc
import pyarrow.dataset as ds
from google.cloud import storage

# %%
# Set up the Google Cloud Storage client and the GCSFS client
fs = gcsfs.GCSFileSystem()

# %% [markdown]
# # Format h5ad files and upload to GCP

# %%
# list all *.h5ad.gz files in the work directory
h5ad_files = sorted(glob(os.path.join(work_dir, '*.h5ad.gz')))
h5ad_files
# Out:
# ['/processed_datasets/scRecount/tahoe/plate10_filtered.h5ad.gz',
#  '/processed_datasets/scRecount/tahoe/plate11_filtered.h5ad.gz',
#  '/processed_datasets/scRecount/tahoe/plate12_filtered.h5ad.gz',
#  '/processed_datasets/scRecount/tahoe/plate13_filtered.h5ad.gz',
#  '/processed_datasets/scRecount/tahoe/plate14_filtered.h5ad.gz',
#  '/processed_datasets/scRecount/tahoe/plate1_filtered.h5ad.gz',
#  '/processed_datasets/scRecount/tahoe/plate2_filtered.h5ad.gz',
#  '/processed_datasets/scRecount/tahoe/plate3_filtered.h5ad.gz',
#  '/processed_datasets/scRecount/tahoe/plate4_filtered.h5ad.gz',
#  '/processed_datasets/scRecount/tahoe/plate5_filtered.h5ad.gz',
#  '/processed_datasets/scRecount/tahoe/plate6_filtered.h5ad.gz',
#  '/processed_datasets/scRecount/tahoe/plate7_filtered.h5ad.gz',
#  '/processed_datasets/scRecount/tahoe/plate8_filtered.h5ad.gz',
#  '/processed_datasets/scRecount/tahoe/plate9_filtered.h5ad.gz']

# %% [markdown]
# # Format h5ad files and upload to GCP

# %%
# columns to keep
to_keep = [
    "sample", "gene_count", "tscp_count", "mread_count", "drugname_drugconc", "drug", 
    "cell_line", "sublibrary", "BARCODE", "pcnt_mito", "S_score", "G2M_score", "phase", 
    "pass_filter", "cell_name"
]

# read in the files
data = []
for infile in h5ad_files:
    print(f"Reading {infile}...")
    df = sc.read_h5ad(infile, backed='r').obs[to_keep]
    # add columns
    df['plate'] = os.path.basename(infile).split('_')[0]
    df['BARCODE_SUB_LIB_ID'] = df.index
    # reorder columns
    cols = df.columns.tolist()
    cols = cols[-2:] + cols[:-2]
    df = df[cols]
    # append
    data.append(df)
 
# combine
df = pd.concat(data, axis=0).reset_index(drop=True)
df

# %%
# write to GCS
outfile = os.path.join(gcp_dir, 'metadata', 'obs_metadata.parquet.gz')
print(f"Writing {outfile}...")
with fs.open(outfile, 'wb') as f:
    df.to_parquet(f, compression='gzip', index=True)
# Out:
# Writing gs://arc-ctc-tahoe100/2025-02-25/metadata/obs_metadata.parquet.gz...

# %%
# group by sample and plate
df_s = df.groupby(['sample', 'plate']).agg({
    'gene_count': 'mean', 
    'tscp_count': 'mean', 
    'mread_count': 'mean',
    'pcnt_mito': 'mean',  
    'drug': 'first',
    'drugname_drugconc': 'first',
}).reset_index().rename(
    columns={
        "gene_count" : "mean_gene_count", 
        "tscp_count" : "mean_tscp_count", 
        "mread_count" : "mean_mread_count",
        "pcnt_mito" : "mean_pcnt_mito"
    }
)

# %%
# write to GCS
outfile = os.path.join(gcp_dir, 'metadata', 'sample_metadata.parquet.gz')
print(f"Writing {outfile}...")
with fs.open(outfile, 'wb') as f:
    df_s.to_parquet(f, compression='gzip')
# Out:
# Writing gs://arc-ctc-tahoe100/2025-02-25/metadata/sample_metadata.parquet.gz...

# %% [markdown]
# # Validate

# %%
# read just the first 3 rows
infile = os.path.join(gcp_dir, 'metadata', 'sample_metadata.parquet.gz')
df = ds.dataset(infile, filesystem=fs, format="parquet").head(3).to_pandas()
df
# Out:
# Reading gs://arc-ctc-tahoe100/2025-02-25/metadata/sample_metadata.parquet.gz...
#         sample    plate  mean_gene_count  mean_tscp_count  mean_mread_count  \
# 0     smp_1495   plate1      1354.169768      2027.115940       2444.032416
# 1     smp_1496   plate1      1404.454157      2226.282791       2690.685970
# 2     smp_1497   plate1      1205.267794      1859.375821       2246.200127
# 3     smp_1498   plate1      1225.510822      1906.494566       2298.907623
# 4     smp_1499   plate1      1231.372881      1861.305085       2245.372881
# ...        ...      ...              ...              ...               ...
# 1339  smp_2834  plate14      1713.499983      3003.519174       3507.489998
# 1340  smp_2835  plate14      1711.157835      2996.269656       3488.079633
# 1341  smp_2836  plate14      1376.900732      2251.751955       2627.752929
# 1342  smp_2837  plate14      1452.439731      2428.145334       2827.406351
# 1343  smp_2838  plate14      1480.101863      2438.533614       2843.864160
#
#       mean_pcnt_mito                       drug  \
# 0           0.033956               Infigratinib
# 1           0.071723               Erdafitinib
# 2           0.084853                 Everolimus
# 3           0.088262                Pemigatinib
# 4           0.050802                Abemaciclib
# ...              ...                        ...
# 1339        0.086085         Anethole trithione
# 1340        0.079115  Clonidine (hydrochloride)
# 1341        0.093560                  Adagrasib
# 1342        0.086081                    DMSO_TF
# 1343        0.071639                    DMSO_TF
#
#                                drugname_drugconc
# 0                 [('Infigratinib', 0.05, 'uM')]
# 1                 [('Erdafitinib ', 0.05, 'uM')]
# 2                   [('Everolimus', 0.05, 'uM')]
# 3                  [('Pemigatinib', 0.05, 'uM')]
# 4                  [('Abemaciclib', 0.05, 'uM')]
# ...                                          ...
# 1339         [('Anethole trithione', 5.0, 'uM')]
# 1340  [('Clonidine (hydrochloride)', 5.0, 'uM')]
# 1341                 [('Adagrasib', 0.05, 'uM')]
# 1342                    [('DMSO_TF', 0.0, 'uM')]
# 1343                    [('DMSO_TF', 0.0, 'uM')]
#
# [1344 rows x 8 columns]

# %%
# read just the first 3 rows
infile = os.path.join(gcp_dir, 'metadata', 'obs_metadata.parquet.gz')
df = ds.dataset(infile, filesystem=fs, format="parquet").head(3).to_pandas()
df
# Out:
#      plate   BARCODE_SUB_LIB_ID    sample  gene_count  tscp_count  \
# 0  plate10  01_001_001-lib_1681  smp_2359        1379        2172
# 1  plate10  01_002_149-lib_1681  smp_2359         975        1256
# 2  plate10  01_003_052-lib_1681  smp_2359         865        1239
#
#    mread_count                           drugname_drugconc  \
# 0         2559  [('Bestatin (hydrochloride)', 0.05, 'uM')]
# 1         1470  [('Bestatin (hydrochloride)', 0.05, 'uM')]
# 2         1446  [('Bestatin (hydrochloride)', 0.05, 'uM')]
#
#                        drug  cell_line sublibrary     BARCODE  pcnt_mito  \
# 0  Bestatin (hydrochloride)  CVCL_1478   lib_1681  01_001_001   0.029926
# 1  Bestatin (hydrochloride)  CVCL_0459   lib_1681  01_002_149   0.026274
# 2  Bestatin (hydrochloride)  CVCL_C466   lib_1681  01_003_052   0.033898
#
#     S_score  G2M_score phase pass_filter   cell_name
# 0 -0.229665  -0.190110    G1        full   NCI-H1573
# 1 -0.167578  -0.132784    G1        full    NCI-H460
# 2 -0.200957  -0.161538    G1        full  hTERT-HPNE

# %% [markdown]
# # sessionInfo

# %%
# !pip list
# Out:
# Package                     Version
# --------------------------- -----------
# aiobotocore                 2.19.0
# aiohappyeyeballs            2.4.4
# aiohttp                     3.11.11
# aioitertools                0.12.0
# aiosignal                   1.3.2
# anndata                     0.11.3
# array_api_compat            1.10.0
# asttokens                   3.0.0
# attrs                       25.1.0
# beautifulsoup4              4.13.3
# botocore                    1.36.3
# Brotli                      1.1.0
# cached-property             1.5.2
# cachetools                  5.5.1
# cellxgene-census            1.16.2
# certifi                     2024.12.14
# cffi                        1.17.1
# charset-normalizer          3.4.1
# colorama                    0.4.6
# comm                        0.2.2
# contourpy                   1.3.1
# cryptography                44.0.0
# cycler                      0.12.1
# debugpy                     1.8.12
# decorator                   5.1.1
# exceptiongroup              1.2.2
# executing                   2.1.0
# fonttools                   4.55.6
# frozenlist                  1.5.0
# fsspec                      2025.2.0
# gcsfs                       2025.2.0
# gget                        0.29.0
# google-api-core             2.24.0
# google-auth                 2.38.0
# google-auth-oauthlib        1.2.1
# google-cloud-core           2.4.2
# google-cloud-secret-manager 2.22.1
# google-cloud-storage        3.0.0
# google-crc32c               1.6.0
# google-resumable-media      2.7.2
# googleapis-common-protos    1.66.0
# grpc-google-iam-v1          0.14.0
# grpcio                      1.67.1
# grpcio-status               1.67.1
# h2                          4.1.0
# h5py                        3.12.1
# hpack                       4.1.0
# hyperframe                  6.1.0
# idna                        3.10
# importlib_metadata          8.6.1
# ipykernel                   6.29.5
# ipython                     8.31.0
# ipywidgets                  8.1.5
# jedi                        0.19.2
# jmespath                    1.0.1
# joblib                      1.4.2
# jupyter_client              8.6.3
# jupyter_core                5.7.2
# jupyterlab_widgets          3.0.13
# kiwisolver                  1.4.8
# legacy-api-wrap             1.4.1
# llvmlite                    0.43.0
# lxml                        5.3.1
# matplotlib                  3.10.0
# matplotlib-inline           0.1.7
# mizani                      0.13.1
# multidict                   6.1.0
# munkres                     1.1.4
# mysql-connector-python      9.0.0
# natsort                     8.4.0
# nest_asyncio                1.6.0
# networkx                    3.4.2
# numba                       0.60.0
# numpy                       1.26.4
# oauthlib                    3.2.2
# packaging                   24.2
# pandas                      2.2.3
# parso                       0.8.4
# patsy                       1.0.1
# pexpect                     4.9.0
# pickleshare                 0.7.5
# pillow                      11.1.0
# pip                         25.0
# platformdirs                4.3.6
# plotnine                    0.14.5
# polars                      1.22.0
# prompt_toolkit              3.0.50
# propcache                   0.2.1
# proto-plus                  1.26.0
# protobuf                    5.28.3
# psutil                      6.1.1
# psycopg2                    2.9.9
# ptyprocess                  0.7.0
# pure_eval                   0.2.3
# pyarrow                     19.0.0
# pyarrow-hotfix              0.6
# pyasn1                      0.6.1
# pyasn1_modules              0.4.1
# pycparser                   2.22
# Pygments                    2.19.1
# pynndescent                 0.5.13
# pyOpenSSL                   25.0.0
# pyparsing                   3.2.1
# PyPika                      0.48.9
# PySocks                     1.7.1
# python-dateutil             2.9.0.post0
# python-dotenv               1.0.1
# pytz                        2024.1
# pyu2f                       0.1.5
# pyzmq                       26.2.0
# requests                    2.32.3
# requests-oauthlib           2.0.0
# rsa                         4.9
# s3fs                        2025.2.0
# scanpy                      1.10.4
# scikit-learn                1.6.1
# scipy                       1.15.1
# seaborn                     0.13.2
# session-info                1.0.0
# setuptools                  75.8.0
# shapely                     2.0.6
# six                         1.17.0
# somacore                    1.0.26
# soupsieve                   2.5
# stack_data                  0.6.3
# statsmodels                 0.14.4
# stdlib-list                 0.11.0
# threadpoolctl               3.5.0
# tiledb                      0.33.3
# tiledbsoma                  1.15.4
# tornado                     6.4.2
# tqdm                        4.67.1
# traitlets                   5.14.3
# typing_extensions           4.12.2
# tzdata                      2025.1
# umap-learn                  0.5.7
# unicodedata2                16.0.0
# urllib3                     2.3.0
# wcwidth                     0.2.13
# wheel                       0.45.1
# widgetsnbextension          4.0.13
# wrapt                       1.17.2
# yarl                        1.18.3
# zipp                        3.21.0
# zstandard                   0.23.0
