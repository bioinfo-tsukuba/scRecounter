# %% [markdown]
# # Description
#
# Tutorial on how to read from the scBaseCamp TileDB-SOMA database

# %% [markdown]
# # Set up
#
# [tiledbsoma-py](https://pypi.org/project/tiledbsoma/) must be installed

# %%
# set the path to the database (local or cloud)
db_uri = "/scratch/multiomics/nickyoungblut/tiledb-loader/tiledb-soma_GeneFull_Ex50pAS"
#db_uri = "/home/nickyoungblut/tmp/tiledb/db_bkup/2025-02-10_tiledb-soma_GeneFull_Ex50pAS"

# %%
# load packages
import numpy as np
import pandas as pd
import tiledbsoma
import tiledbsoma.io

# %% [markdown]
# # Observations

# %%
# get obs colnames 
with tiledbsoma.open(db_uri) as exp:
    print(exp.obs.schema)
# Out:
# soma_joinid: int64 not null
# obs_id: large_string
# gene_count: int64
# umi_count: float
# barcode: large_string
# SRX_accession: dictionary<values=string, indices=int32, ordered=0>
# lib_prep: dictionary<values=string, indices=int32, ordered=0>
# tech_10x: dictionary<values=string, indices=int32, ordered=0>
# organism: dictionary<values=string, indices=int32, ordered=0>
# tissue: dictionary<values=string, indices=int32, ordered=0>
# disease: dictionary<values=string, indices=int32, ordered=0>
# purturbation: dictionary<values=string, indices=int32, ordered=0>
# cell_line: dictionary<values=string, indices=int32, ordered=0>
# czi_collection_id: dictionary<values=string, indices=int32, ordered=0>
# czi_collection_name: dictionary<values=string, indices=int32, ordered=0>

# %%
# view all metadata for the first 3 observations
with tiledbsoma.Experiment.open(db_uri) as exp:
    df = (
        exp.obs.read()
        .concat()
        .slice(0,3) 
        .to_pandas()
    )
pd.set_option('display.max_columns', 100)
df
# Out:
#    soma_joinid                        obs_id  gene_count  umi_count  \
# 0            0  AAACCCAAGGGAGATA_SRX10681588        1677     4085.0
# 1            1  AAACCCAAGGTTGGAC_SRX10681588        1371     3866.0
# 2            2  AAACCCACAGTGGTGA_SRX10681588        1891     3936.0
#
#             barcode SRX_accession      lib_prep     tech_10x organism tissue  \
# 0  AAACCCAAGGGAGATA   SRX10681588  10x_Genomics  3_prime_gex    human  blood
# 1  AAACCCAAGGTTGGAC   SRX10681588  10x_Genomics  3_prime_gex    human  blood
# 2  AAACCCACAGTGGTGA   SRX10681588  10x_Genomics  3_prime_gex    human  blood
#
#          disease purturbation       cell_line czi_collection_id  \
# 0  not specified         lean  not applicable              None
# 1  not specified         lean  not applicable              None
# 2  not specified         lean  not applicable              None
#
#   czi_collection_name
# 0                None
# 1                None
# 2                None

# %%
# count total observations
with tiledbsoma.open(db_uri) as exp:
    total_cells = (
        exp.obs.read(column_names=["obs_id"])
        .concat()
        .group_by([])
        .aggregate([
            ([], 'count_all'),
        ])
        .to_pandas()["count_all"].values[0]
    )
print(f"Total cells: {total_cells}")
# Out:
# Total cells: 154151716

# %%
# observations per dataset
with tiledbsoma.Experiment.open(db_uri) as exp:
    df = (
        exp.obs.read(column_names=["SRX_accession"])
        .concat()
        .group_by(["SRX_accession"])
        .aggregate([
            ([], 'count_all'),
        ])
        .sort_by([("count_all", "descending")])
        .to_pandas()
    )
df
# Out:
#       SRX_accession  count_all
# 0       SRX15016115     148051
# 1       SRX19719427     107903
# 2       SRX15016116     103365
# 3       SRX22915751     100908
# 4       SRX17521046      98235
# ...             ...        ...
# 20289   SRX15483880         47
# 20290    SRX6640133         47
# 20291   SRX21168907         42
# 20292   SRX19326000         12
# 20293    SRX7059415         10
#
# [20294 rows x 2 columns]

# %% [markdown]
# ## Metadata

# %% [markdown]
# ### Summary

# %%
# obs count per 10X Genomics technology
with tiledbsoma.Experiment.open(db_uri) as exp:
    df = (
        exp.obs.read(column_names=["tech_10x"])
        .concat()
        .group_by(["tech_10x"])
        .aggregate([
            ([], 'count_all'),
        ])
        .sort_by([("count_all", "descending")])
        .to_pandas()
    )
df
# Out:
#              tech_10x  count_all
# 0         3_prime_gex  115098143
# 1         5_prime_gex   25183677
# 2            multiome    4778869
# 3   feature_barcoding    2163264
# 4                 vdj    2132920
# 5      not_applicable     997406
# 6               other     973283
# 7                 NaN     489760
# 8            cellplex     291407
# 9                 NaN     247285
# 10               atac      18685
# 11          fixed_rna       7410

# %%
# obs count per organism
with tiledbsoma.Experiment.open(db_uri) as exp:
    df = (
        exp.obs.read(column_names=["organism"])
        .concat()
        .group_by(["organism"])
        .aggregate([
            ([], 'count_all'),
        ])
        .sort_by([("count_all", "descending")])
        .to_pandas()
    )
df
# Out:
#   organism  count_all
# 0    human   80575883
# 1    mouse   69485617
# 2      NaN    1830849
# 3      NaN     489760

# %% [markdown]
# ### Query

# %%
# create metadata query
obs_query = tiledbsoma.AxisQuery(value_filter='organism in ["human"]')

# obs count per 10X Genomics technology for the query results
with tiledbsoma.Experiment.open(db_uri) as exp:
    df = (
        exp.axis_query("RNA", obs_query=obs_query)
        .obs()
        .concat()
        .group_by(["organism", "tech_10x"])
        .aggregate([
            ([], 'count_all'),
        ])
        .sort_by([("count_all", "descending")])
        .to_pandas()
    )
df
# Out:
#   organism           tech_10x  count_all
# 0    human        3_prime_gex   51452698
# 1    human        5_prime_gex   16149396
# 2    human           multiome    2241595
# 3    human  feature_barcoding    1772353
# 4    human                vdj    1570771
# 5    human     not_applicable     537019
# 6    human              other     521553
# 7    human           cellplex      80411
# 8    human               atac      15988

# %%
# create metadata query
obs_query = tiledbsoma.AxisQuery(
    value_filter='organism in ["human"] and tech_10x in ["cellplex"] and gene_count >= 1000'
)

# gene and umi counts
with tiledbsoma.Experiment.open(db_uri) as exp:
    df = (
        exp.axis_query("RNA", obs_query=obs_query)
        .obs()
        .concat()
        .select(["SRX_accession", "gene_count", "umi_count"])
        .sort_by([("gene_count", "descending")])
        .to_pandas()
    )
df
# Out:
#       SRX_accession  gene_count  umi_count
# 0       SRX22369542       14245   272316.0
# 1       SRX22369542       14093   272180.0
# 2       SRX22369542       14056   282893.0
# 3       SRX22369542       14018   253654.0
# 4       SRX22369542       13895   265843.0
# ...             ...         ...        ...
# 46232   SRX22519782        1000     1372.0
# 46233   SRX22519782        1000     1382.0
# 46234   SRX22519782        1000     1648.0
# 46235   SRX22519782        1000     1612.0
# 46236   SRX22519782        1000     1462.0
#
# [46237 rows x 3 columns]

# %%
# filter to target accessions

## create query
target_acc = [
    "SRX24745432", "SRX17878115", "SRX21370979", "SRX25986076", "SRX25986075", "SRX25986079", 
    "SRX17878109", "SRX21370976", "SRX21370978", "SRX17878114", "SRX21370977", "SRX17878113",
    "SRX25986074", "SRX17878104", "SRX17878105", "SRX17878112", "SRX20300901", "SRX20300902",
    "SRX20300905", "SRX20300900", "SRX17878106", "SRX24534638", "SRX17878111", "SRX21370974",
    "SRX21370975", "SRX20300906", "SRX20300903", "SRX20300899", "SRX17878110", "SRX17878107",
    "SRX20300904", "SRX17878108"
]
target_acc = ",".join([f'"{x}"' for x in target_acc])
obs_query = tiledbsoma.AxisQuery(value_filter=f'SRX_accession in [{target_acc}]')

## query the database
with tiledbsoma.Experiment.open(db_uri) as exp:
    df = (
        exp.axis_query("RNA", obs_query=obs_query)
        .obs()
        .concat()
        .group_by(["SRX_accession", "organism", "tech_10x"])
        .aggregate([
            ([], 'count_all'),
        ])
        .sort_by([("count_all", "descending")])
        .to_pandas()
    )
df
# Out:
#    SRX_accession organism     tech_10x  count_all
# 0    SRX24745432    human     multiome      24079
# 1    SRX17878115    human  3_prime_gex      12815
# 2    SRX21370979    human  5_prime_gex      10135
# 3    SRX25986076    human  3_prime_gex       9395
# 4    SRX25986075    human  3_prime_gex       8654
# 5    SRX25986079    human  3_prime_gex       8353
# 6    SRX17878109    human  3_prime_gex       7067
# 7    SRX21370976    human  5_prime_gex       6711
# 8    SRX17878114    human  3_prime_gex       6385
# 9    SRX21370977    human  5_prime_gex       6372
# 10   SRX17878113    human  3_prime_gex       6357
# 11   SRX25986074    human  3_prime_gex       5802
# 12   SRX17878104    human  3_prime_gex       4741
# 13   SRX17878105    human  3_prime_gex       4143
# 14   SRX17878112    human  3_prime_gex       3720
# 15   SRX20300901    mouse  3_prime_gex       3582
# 16   SRX20300902    mouse  3_prime_gex       3450
# 17   SRX20300905    mouse  3_prime_gex       3036
# 18   SRX20300900    mouse  3_prime_gex       2956
# 19   SRX17878106    human  3_prime_gex       2894
# 20   SRX24534638    human  3_prime_gex       2870
# 21   SRX17878111    human  3_prime_gex       2816
# 22   SRX21370974    human  5_prime_gex       2254
# 23   SRX21370975    human  5_prime_gex       2139
# 24   SRX20300906    mouse  3_prime_gex       2132
# 25   SRX20300903    mouse  3_prime_gex       2049
# 26   SRX20300899    mouse  3_prime_gex       2045
# 27   SRX17878110    human  3_prime_gex       2024
# 28   SRX17878107    human  3_prime_gex       1993
# 29   SRX20300904    mouse  3_prime_gex       1937
# 30   SRX17878108    human  3_prime_gex       1414

# %% [markdown]
# ### CZI collection datasets

# %%
# create metadata query
obs_query = tiledbsoma.AxisQuery(value_filter='czi_collection_name in ["None", "NaN"]')

# obs count per 10X Genomics technology for the query results
with tiledbsoma.Experiment.open(db_uri) as exp:
    df = (
        exp.axis_query("RNA", obs_query=obs_query)
        .obs()
        .concat()
        .group_by(["czi_collection_name"])
        .aggregate([
            ([], 'count_all'),
        ])
        .sort_by([("count_all", "descending")])
        .to_pandas()
    )
df
# Out:
#   czi_collection_name  count_all
# 0                None  150061500

# %%
# create metadata query
obs_query = tiledbsoma.AxisQuery(value_filter='czi_collection_name != "None"')

# obs count per 10X Genomics technology for the query results
with tiledbsoma.Experiment.open(db_uri) as exp:
    df = (
        exp.axis_query("RNA", obs_query=obs_query)
        .obs()
        .concat()
        .group_by(["czi_collection_name"])
        .aggregate([
            ([], 'count_all'),
        ])
        .sort_by([("count_all", "descending")])
        .to_pandas()
    )
df
# Out:
#                                   czi_collection_name  count_all
# 0   Spatial proteogenomics reveals distinct and ev...     189890
# 1   Developmental cell programs are co-opted in in...     153916
# 2   Cross-tissue immune cell analysis reveals tiss...     139896
# 3       Human CellCards Multi-Study CellRef 1.0 Atlas     115615
# 4   A spatially resolved atlas of the human lung c...     112047
# 5   Single-cell eQTL mapping identifies cell type ...     104481
# 6   COVID-19 mRNA vaccine elicits a potent adaptiv...      98848
# 7   HypoMap – a unified single cell gene express...      97187
# 8   Multi-scale spatial mapping of cell population...      81460
# 9                      Cells of the adult human heart      74823
# 10  Humoral immunity at the brain borders in homeo...      65517
# 11  Inflammatory blockade prevents injury to the d...      63187
# 12  Single Cell Multiome Atlas of the Human Fetal ...      51781
# 13  Unified comprehensive single-cell atlas of the...      47947
# 14  Epithelial zonation along the mammalian small ...      39375
# 15                                        iPain atlas      35486
# 16  An Integrated Single Cell Atlas of Human Perio...      29639
# 17  Transcriptional responses of the human dorsal ...      27222
# 18  Integrated adult and foetal heart single-cell ...      26141
# 19  Early human lung immune cell development and i...      23776
# 20  Single-cell transcriptomics of human T cells r...      22185
# 21  Harmonized single-cell landscape, intercellula...      20815
# 22  Multimodal single cell sequencing implicates c...      20484
# 23  An alternative cell cycle coordinates multicil...      19902
# 24  Single-cell transcriptome profiling of the hum...      18525
# 25  Time-resolved Systems Immunology Reveals a Lat...      18419
# 26  Single-cell genomics improves the discovery of...      17056
# 27  Multi-omic profiling of the developing human c...      16825
# 28  Stress-induced RNA–chromatin interactions pr...      14836
# 29                        Human Trophoblast Organoids      14210
# 30  A transcriptional cross species map of pancrea...      14189
# 31                 Human skeletal muscle ageing atlas      12222
# 32  Integrated scRNA-Seq Identifies Human Postnata...      11416
# 33  Single cell transcriptional and chromatin acce...      11173
# 34  Spatiotemporal analysis of human intestinal de...       7071
# 35  Single-Cell Analysis of Crohn’s Disease Lesi...       6292
# 36  Immune microniches shape intestinal Treg function       4650
# 37  Construction of a human cell landscape at sing...       1503
# 38  Single-cell transcriptomics of the human retin...        842

# %%
# total counts
df["count_all"].sum()
# Out:
# 1830849

# %%
# number of SRX accessions per czi collection

# create metadata query
obs_query = tiledbsoma.AxisQuery(value_filter='czi_collection_name != "None"')

# obs count per 10X Genomics technology for the query results
with tiledbsoma.Experiment.open(db_uri) as exp:
    df = (
        exp.axis_query("RNA", obs_query=obs_query)
        .obs()
        .concat()
        .group_by(["SRX_accession", "czi_collection_name"])
        .aggregate([])
        .group_by(["czi_collection_name"])
        .aggregate([
            ([], 'count_all'),
        ])
        .sort_by([("count_all", "descending")])
        .to_pandas()
    )
df
# Out:
#                                   czi_collection_name  count_all
# 0   Cross-tissue immune cell analysis reveals tiss...         52
# 1   A spatially resolved atlas of the human lung c...         34
# 2   Spatial proteogenomics reveals distinct and ev...         27
# 3       Human CellCards Multi-Study CellRef 1.0 Atlas         22
# 4   Developmental cell programs are co-opted in in...         22
# 5                      Cells of the adult human heart         19
# 6   Construction of a human cell landscape at sing...         13
# 7   Humoral immunity at the brain borders in homeo...         12
# 8   COVID-19 mRNA vaccine elicits a potent adaptiv...         11
# 9   HypoMap – a unified single cell gene express...          9
# 10  Early human lung immune cell development and i...          8
# 11  Harmonized single-cell landscape, intercellula...          7
# 12  Unified comprehensive single-cell atlas of the...          7
# 13  Multi-scale spatial mapping of cell population...          6
# 14  An Integrated Single Cell Atlas of Human Perio...          5
# 15  Inflammatory blockade prevents injury to the d...          5
# 16                                        iPain atlas          5
# 17  Single-cell eQTL mapping identifies cell type ...          5
# 18  Multi-omic profiling of the developing human c...          4
# 19  Single-cell transcriptomics of human T cells r...          4
# 20  Single Cell Multiome Atlas of the Human Fetal ...          4
# 21  Stress-induced RNA–chromatin interactions pr...          4
# 22  Integrated adult and foetal heart single-cell ...          3
# 23  Multimodal single cell sequencing implicates c...          3
# 24  Transcriptional responses of the human dorsal ...          3
# 25  Single-cell transcriptome profiling of the hum...          3
# 26  An alternative cell cycle coordinates multicil...          2
# 27  Single cell transcriptional and chromatin acce...          2
# 28  Spatiotemporal analysis of human intestinal de...          2
# 29  Epithelial zonation along the mammalian small ...          2
# 30  Integrated scRNA-Seq Identifies Human Postnata...          2
# 31                 Human skeletal muscle ageing atlas          2
# 32                        Human Trophoblast Organoids          2
# 33  Immune microniches shape intestinal Treg function          2
# 34  Single-cell genomics improves the discovery of...          2
# 35  A transcriptional cross species map of pancrea...          1
# 36  Time-resolved Systems Immunology Reveals a Lat...          1
# 37  Single-Cell Analysis of Crohn’s Disease Lesi...          1
# 38  Single-cell transcriptomics of the human retin...          1

# %%
# SRX accession count
df["count_all"].sum()
# Out:
# 319

# %% [markdown]
# # Variables

# %%
# get colnames
with tiledbsoma.open(db_uri) as exp:
    print(exp.ms["RNA"].var.schema)
# Out:
# soma_joinid: int64 not null
# var_id: large_string

# %%
# read in the var level data
with tiledbsoma.Experiment.open(db_uri) as exp:
    df = (
        exp.ms["RNA"]
        .var.read(column_names=["soma_joinid", "var_id"])
        .concat()
        .to_pandas()
    )
df
# Out:
#        soma_joinid              var_id
# 0                0     ENSG00000000003
# 1                1     ENSG00000000005
# 2                2     ENSG00000000419
# 3                3     ENSG00000000457
# 4                4     ENSG00000000460
# ...            ...                 ...
# 95411        95411  ENSMMUG00000065379
# 95412        95412  ENSMMUG00000065380
# 95413        95413  ENSMMUG00000065382
# 95414        95414  ENSMMUG00000065383
# 95415        95415  ENSMMUG00000065387
#
# [95416 rows x 2 columns]

# %%
# count the number of ensembl IDs per organism
df["var_id"].replace(r"\d+$", "", regex=True).value_counts()
# Out:
# var_id
# ENSG       36601
# ENSMUSG    32285
# ENSMMUG    26530
# Name: count, dtype: int64

# %% [markdown]
# # Counts

# %% [markdown]
# ## Slice

# %%
# sparse count matrix for the first 3 observations
with tiledbsoma.Experiment.open(db_uri) as exp:
    print(
        exp.ms["RNA"].X["data"]
        .read((slice(0,3),))
        .coos()
        .concat() 
    )
# Out:
# <pyarrow.SparseCOOTensor>
# type: float
# shape: (52967109, 68886)

# %%
# Get gene count per obs
def get_genes_per_obs(db_uri, start, end):
    with tiledbsoma.Experiment.open(db_uri) as exp:
        data = (
            exp.ms["RNA"].X["data"]
            .read((slice(start, end),)).coos().concat()
        )
    return np.diff(data.to_scipy().tocsr().indptr)[start:end]

## first 10 observations
get_genes_per_obs(db_uri, 0, 10)
# Out:
# array([1677, 1371, 1891, 1967, 2050, 1303, 3151, 1705, 1276, 1507],
#       dtype=int32)

# %%
# Get UMI count per obs
def get_umi_counts_per_obs(db_uri, start, end):
    with tiledbsoma.Experiment.open(db_uri) as exp:
        data = exp.ms["RNA"].X["data"].read((slice(start, end),)).coos().concat()
    sp = data.to_scipy().tocsr()
    return sp.sum(axis=1).A1[start:end]

## first 10 observations
get_umi_counts_per_obs(db_uri, 0, 10)
# Out:
# array([4085., 3866., 3936., 5528., 6013., 2288., 7996., 4050., 3031.,
#        4726.], dtype=float32)

# %% [markdown]
# #
